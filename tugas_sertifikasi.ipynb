# %% [markdown]
# <a href="https://colab.research.google.com/github/rii92/Datmin/blob/main/tugas_sertifikasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Memasang dan memuat paket
install.packages("randomForest")
library(randomForest)

# Memuat dataset (Ganti 'path_to_your_data' dengan lokasi dataset Anda)
HousePricesDataset <- read.csv("https://raw.githubusercontent.com/rii92/tutorial-ai/main/data1.csv")
HousePricesDataset

creditapproval <- read.csv("https://raw.githubusercontent.com/rii92/tutorial-ai/main/data2.csv")
creditapproval
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#     house_sqft num_of_bedrooms num_of_bathrooms year_built tax_assessed_value
# 1   1770        3                2              1990       195000
# 2   1770       NA                2              1990       195000
# 3   1770       NA                2              1990       195000
# 4   1772       NA                2              1990       200000
# 5   1850       NA               25                NA       200000
# 6   1850       NA               25                NA       200000
# 7   1850        3               25                NA       205000
# 8   1850        3               25                NA       205000
# 9   1850        3              300                NA       205000
# 10  1850        3               25                NA       205000
# 11    NA        3               25                NA       212000
# 12    NA        3              500              1990       212000
# ...
